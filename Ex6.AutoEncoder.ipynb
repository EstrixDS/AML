# %% [markdown]
# <img src="https://www.th-koeln.de/img/logo.svg" style="float:right;" width="200">

# %% [markdown]
# # 6th exercise: <font color="#C70039">Work with Autoencoders for anomaly detection</font>
# * Course: AML
# * Lecturer: <a href="https://www.gernotheisenberg.de/">Gernot Heisenberg</a>
# * Author of notebook: <a href="https://www.gernotheisenberg.de/">Gernot Heisenberg</a>
# * Date: 11.12.2022
# * editor: Tobias Esser
# * matriculation number: 11134729
#
# <img src="https://blog.keras.io/img/ae/autoencoder_schema.jpg" style="float: center;" width="700">
#
# ---------------------------------
# **GENERAL NOTE 1**:
# Please make sure you are reading the entire notebook, since it contains a lot of information on your tasks (e.g. regarding the set of certain paramaters or a specific computational trick), and the written mark downs as well as comments contain a lot of information on how things work together as a whole.
#
# **GENERAL NOTE 2**:
# * Please, when commenting source code, just use English language only.
# * When describing an observation please use English language, too.
# * This applies to all exercises throughout this course.
#
# ---------------------------------
#
# ### <font color="ce33ff">DESCRIPTION</font>:
# Autoencoder is an unsupervised artificial neural network (ANN) that learns how to efficiently compress and encode data and then learns how to reconstruct the data back from the reduced encoded representation to a representation that is as close to the original input as possible.
#
# An Autoencoder reduces data dimensions by learning how to ignore the noise in the data and thus outliers.
# In the section above, you can seen an example of the input/output image from the MNIST dataset to an Autoencoder.
#
# #### Autoencoder Components:
# An Autoencoder consists of four main parts:
#
# 1. Encoder: In which the model learns how to reduce the input dimensions and compress the input data into an encoded representation.
#
# 2. Bottleneck: which is the layer that contains the compressed representation of the input data. This is the lowest possible dimensions of the input data. The bottlneck is also called latent vector. The concept of the latent space and latent vectors becomes important later on as we move forward to understand Generative Models.
#
# 3. Decoder: In which the model learns how to reconstruct the data from the encoded representation to be as close to the original input as possible.
#
# 4. Reconstruction Loss: This is the method that measures how well the decoder is performing and how close the output is to the original input.
#
# As always in ANNs, the training itself involves back propagation in order to minimize the network’s reconstruction loss.
#
# Due to this features of an Autoencoder the use cases are manyfold. One of the obviously is anomaly detection.
#
# #### Autoencoder Architecture:
#
# The network architecture for Autoencoders can vary between simple Feed Forward networks, Recurrent Neural Networks (LSTM) or Convolutional Neural Networks (CNN) depending on the use case.
#
# ---------------------------------
#
# ### <font color="FFC300">TASKS</font>:
# The tasks that you need to work on within this notebook are always indicated below as bullet points.
# If a task is more challenging and consists of several steps, this is indicated as well.
# Make sure you have worked down the task list and commented your doings.
# This should be done by using markdown.<br>
# <font color=red>Make sure you don't forget to specify your name and your matriculation number in the notebook.</font>
#
# **YOUR TASKS in this exercise are as follows**:
# 1. import the notebook to Google Colab or use your local machine.
# 2. make sure you specified you name and your matriculation number in the header below my name and date.
# * set the date too and remove mine.
# 3. read the entire notebook carefully
# * add comments whereever you feel it necessary for better understanding
# * run the notebook for the first time.
# * the example below shows how to use an autoencoder for anomaly detection
#
# 4. <font color=green>Develop an Autoencoder for Domain Adaptation (Me -> Walter White ). You can of course also take own data, e.g. a photo of yours and someone else.</font>
# 5. Set at least the following hyperparameters for training (epochs=100000, shuffle=True).
# 6. Implement a CNN for working out important features for the adaptation. If you feel lost in the exercise, please visit the sample solution.
# 7. There is also an implementation of data augmentation that helps you building up your data set from one single "original" image.
# ---------------------------------

# %% [markdown]
# ### Auto-Encoding
# If you have correlated input data, the auto-encoder method will work very well because the encoding operation relies on the correlated features to compress the data.
# Let’s consider that an auto-encoder is trained on the MNIST dataset.
# As you know already, using a simple FeedForward neural network, this can be done by building a simple 6 layers network as below:

# %%
import numpy as np
import keras
from keras.datasets import mnist
from keras.models import Sequential, Model
from keras.layers import Dense, Input
from keras import optimizers
from keras.optimizers import Adam

# load the inbuild mnist data set (8bit grayscale digits)
# https://en.wikipedia.org/wiki/MNIST_database
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# normalize the training and the validation data set
train_x = x_train.reshape(60000, 784) / 255
val_x = x_test.reshape(10000, 784) / 255

# build the auto-encoding layers
autoencoder = Sequential()
autoencoder.add(Dense(512,activation='elu', input_shape=(784,)))
autoencoder.add(Dense(128,activation='elu'))
autoencoder.add(Dense(10, activation='linear', name="bottleneck"))
autoencoder.add(Dense(128,activation='elu'))
autoencoder.add(Dense(512,activation='elu'))
autoencoder.add(Dense(784,activation='sigmoid'))
autoencoder.compile(loss='mean_squared_error', optimizer = Adam())

'''
NOTE:
-----
The Exponential Linear Unit (ELU) is an activation function for neural networks. 
In contrast to ReLUs (which you know), ELUs have negative values which allows them to push mean unit 
activations closer to zero like batch normalization but with lower computational complexity.
'''

# train the model and finally assign the encoding to the decoder
'''
NOTE:
-----
make sure you understand, that you are training on train_x and not on train_y but train_x again for the reconstruction
the same for the validation (val_x, val_x)
'''
trained_model = autoencoder.fit(train_x, train_x, batch_size=1024, epochs=10, verbose=1, validation_data=(val_x, val_x))
encoder = Model(autoencoder.input, autoencoder.get_layer('bottleneck').output)

encoded_data = encoder.predict(train_x)# bottleneck representation

decoded_output = autoencoder.predict(train_x)# reconstruction
encoding_dim = 10

# return the decoder
encoded_input = Input(shape=(encoding_dim,))
decoder = autoencoder.layers[-3](encoded_input)
decoder = autoencoder.layers[-2](decoder)
decoder = autoencoder.layers[-1](decoder)
decoder = Model(encoded_input, decoder)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 59/59 [==============================] - 4s 48ms/step - loss: 0.0752 - val_loss: 0.0513
# Epoch 2/10
# 59/59 [==============================] - 2s 41ms/step - loss: 0.0439 - val_loss: 0.0370
# Epoch 3/10
# 59/59 [==============================] - 2s 37ms/step - loss: 0.0335 - val_loss: 0.0298
# Epoch 4/10
# 59/59 [==============================] - 2s 37ms/step - loss: 0.0286 - val_loss: 0.0264
# Epoch 5/10
# 59/59 [==============================] - 2s 37ms/step - loss: 0.0257 - val_loss: 0.0241
# Epoch 6/10
# 59/59 [==============================] - 2s 37ms/step - loss: 0.0239 - val_loss: 0.0228
# Epoch 7/10
# 59/59 [==============================] - 2s 39ms/step - loss: 0.0225 - val_loss: 0.0216
# Epoch 8/10
# 59/59 [==============================] - 2s 39ms/step - loss: 0.0215 - val_loss: 0.0206
# Epoch 9/10
# 59/59 [==============================] - 2s 41ms/step - loss: 0.0206 - val_loss: 0.0198
# Epoch 10/10
# 59/59 [==============================] - 2s 40ms/step - loss: 0.0199 - val_loss: 0.0192
# 1875/1875 [==============================] - 4s 2ms/step
# 1875/1875 [==============================] - 6s 3ms/step

# %% [markdown]
# As you can see in the output, the last reconstruction loss/error for the validation set is approx. 0.0197, which is great.
# Now, if we pass any normal image from the MNIST dataset, the reconstruction loss will be very low (< 0.02) BUT if we tried to pass any other different image (outlier / anomaly), we will get a high reconstruction loss value because the network failed to reconstruct the image/input that is considered an anomaly.
#
# Notice in the code above, you can use only the encoder part to compress some data or images and you can also only use the decoder part to decompress the data by loading the decoder layers.

# %% [markdown]
# #### Auto-Encoders for Anomaly Detection
# Now, let’s do some anomaly detection. The code below uses two different images to predict the anomaly score (reconstruction error) using the autoencoder network we trained above.
#
# The first image is from the MNIST and the result is error=2.46241018. This means that the image is not an anomaly. The second image (yoda.png) obviously does not belong to the training dataset and the result is: error=2727.0718. This high error means that the image is an anomaly. Even the third image. The same concept applies to any type of dataset.

# %%
import os
import cv2
from tqdm import tqdm
from keras.utils import img_to_array
import time
SIZE=256

# import input img
input_img_data=[]
input_path = './data/heisenberg_heisenberg/gernot/'
files=os.listdir(input_path)
# read all images in the folder (different rotations and flips of the original)
for i in tqdm(files):
    img=cv2.imread(input_path+'/'+i,1) #Change 0 to 1 for color images
    img=cv2.resize(img,(SIZE, SIZE))
    input_img_data.append(img_to_array(img))
# -----------------------------------------
# import output_img
output_img_data=[]
output_path = './data/heisenberg_heisenberg/walter/'
files=os.listdir(output_path)
# read all images in the folder (same rotations and flips as img)
for i in tqdm(files):
    img=cv2.imread(output_path+'/'+i,1)#Change 0 to 1 for color images
    img=cv2.resize(img,(SIZE, SIZE))
    output_img_data.append(img_to_array(img))

input_img_array = np.reshape(input_img_data, (len(input_img_data), SIZE, SIZE, 3))
input_img_array = input_img_array.astype('float32') / 255. # normalize
output_img_array= np.reshape(output_img_data, (len(output_img_data), SIZE, SIZE, 3))
output_img_array = output_img_array.astype('float32') / 255. # normalize

# Original image for prediction of output_img 
# this one does not belong to the training set
test_img_data=[]

test_img=cv2.imread('./data/heisenberg_heisenberg/gernot-heisenberg-original.jpg', 1) #Change 0 to 1 for color images
test_img = cv2.cvtColor(test_img, cv2.COLOR_BGR2RGB)#Changing BGR to RGB to show images in true colors
test_img=cv2.resize(test_img,(SIZE, SIZE))
test_img_data.append(img_to_array(test_img))

test_img_array = np.reshape(test_img_data, (len(test_img_data), SIZE, SIZE, 3))
test_img_array = test_img_array.astype('float32') / 255. # normalize

# set the start time
# later needed for calculating the computation time
start=time.time()
# Out:
# 100%|██████████| 50/50 [00:00<00:00, 157.73it/s]
# 100%|██████████| 50/50 [00:00<00:00, 155.76it/s]

# %%
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D
model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(SIZE, SIZE, 3)))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))
 
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(3, (3, 3), activation='relu', padding='same'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

# fit the model of input_img to output_img 
epochs = 15000
model.fit(input_img_array, output_img_array, epochs=epochs, shuffle=True)

# print out the computation time
finish=time.time()
print('total computation time = ', finish-start)

# save the model
model.save("domain_adapt_autoenc_epochs." + str(epochs) + ".model")
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_151 (Conv2D)         (None, 256, 256, 32)      896
#
#  max_pooling2d_68 (MaxPoolin  (None, 128, 128, 32)     0
#  g2D)
#
#  conv2d_152 (Conv2D)         (None, 128, 128, 8)       2312
#
#  max_pooling2d_69 (MaxPoolin  (None, 64, 64, 8)        0
#  g2D)
#
#  conv2d_153 (Conv2D)         (None, 64, 64, 8)         584
#
#  max_pooling2d_70 (MaxPoolin  (None, 32, 32, 8)        0
#  g2D)
#
#  conv2d_154 (Conv2D)         (None, 32, 32, 8)         584
#
#  up_sampling2d_60 (UpSamplin  (None, 64, 64, 8)        0
#  g2D)
#
#  conv2d_155 (Conv2D)         (None, 64, 64, 8)         584
#
#  up_sampling2d_61 (UpSamplin  (None, 128, 128, 8)      0
#  g2D)
#
#  conv2d_156 (Conv2D)         (None, 128, 128, 32)      2336
#
#  up_sampling2d_62 (UpSamplin  (None, 256, 256, 32)     0
#  g2D)
#
#  conv2d_157 (Conv2D)         (None, 256, 256, 3)       867
#
# =================================================================
# Total params: 8,163
# Trainable params: 8,163
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15000
# 2/2 [==============================] - 5s 1s/step - loss: 2.5922 - accuracy: 0.0328
# Epoch 2/15000
# 2/2 [==============================] - 4s 1s/step - loss: 1.0351 - accuracy: 0.0826
# Epoch 3/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.8532 - accuracy: 0.3077
# Epoch 4/15000
# 2/2 [==============================] - 3s 1s/step - loss: 0.7537 - accuracy: 0.6862
# Epoch 5/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.6898 - accuracy: 0.8793
# Epoch 6/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.6515 - accuracy: 0.9004
# Epoch 7/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.6365 - accuracy: 0.9152
# Epoch 8/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.6384 - accuracy: 0.9306
# Epoch 9/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.6416 - accuracy: 0.9400
# Epoch 10/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.6386 - accuracy: 0.9467
# Epoch 11/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.6314 - accuracy: 0.9546
# Epoch 12/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.6232 - accuracy: 0.9582
# Epoch 13/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.6166 - accuracy: 0.9605
# Epoch 14/15000
# 2/2 [==============================] - 4s 2s/step - loss: 0.6134 - accuracy: 0.9578
# Epoch 15/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.6130 - accuracy: 0.9561
# Epoch 16/15000
# 2/2 [==============================] - 5s 2s/step - loss: 0.6137 - accuracy: 0.9561
# Epoch 17/15000
# 2/2 [==============================] - 6s 2s/step - loss: 0.6142 - accuracy: 0.9562
# Epoch 18/15000
# 2/2 [==============================] - 5s 2s/step - loss: 0.6133 - accuracy: 0.9578
# Epoch 19/15000
# 2/2 [==============================] - 3s 1s/step - loss: 0.6110 - accuracy: 0.9588
# Epoch 20/15000
# 2/2 [==============================] - 3s 1s/step - loss: 0.6081 - accuracy: 0.9588
# Epoch 21/15000
# 2/2 [==============================] - 3s 1s/step - loss: 0.6060 - accuracy: 0.9588
# Epoch 22/15000
# 2/2 [==============================] - 3s 1s/step - loss: 0.6042 - accuracy: 0.9586
# Epoch 23/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.6037 - accuracy: 0.9581
# Epoch 24/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.6027 - accuracy: 0.9582
# Epoch 25/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.6007 - accuracy: 0.9605
# Epoch 26/15000
# 2/2 [==============================] - 3s 1s/step - loss: 0.5990 - accuracy: 0.9610
# Epoch 27/15000
# 2/2 [==============================] - 3s 1s/step - loss: 0.5979 - accuracy: 0.9614
# Epoch 28/15000
# 2/2 [==============================] - 3s 1s/step - loss: 0.5970 - accuracy: 0.9614
# Epoch 29/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5961 - accuracy: 0.9614
# Epoch 30/15000
# 2/2 [==============================] - 3s 1s/step - loss: 0.5950 - accuracy: 0.9613
# Epoch 31/15000
# 2/2 [==============================] - 3s 1s/step - loss: 0.5939 - accuracy: 0.9612
# Epoch 32/15000
# 2/2 [==============================] - 4s 2s/step - loss: 0.5930 - accuracy: 0.9612
# Epoch 33/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5919 - accuracy: 0.9613
# Epoch 34/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5912 - accuracy: 0.9613
# Epoch 35/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5901 - accuracy: 0.9614
# Epoch 36/15000
# 2/2 [==============================] - 3s 1s/step - loss: 0.
15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5211 - accuracy: 0.9618
# Epoch 14880/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5213 - accuracy: 0.9616
# Epoch 14881/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5224 - accuracy: 0.9614
# Epoch 14882/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5211 - accuracy: 0.9614
# Epoch 14883/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5211 - accuracy: 0.9614
# Epoch 14884/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5211 - accuracy: 0.9616
# Epoch 14885/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5209 - accuracy: 0.9617
# Epoch 14886/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5213 - accuracy: 0.9618
# Epoch 14887/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5214 - accuracy: 0.9618
# Epoch 14888/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5212 - accuracy: 0.9618
# Epoch 14889/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5216 - accuracy: 0.9618
# Epoch 14890/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5216 - accuracy: 0.9618
# Epoch 14891/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5217 - accuracy: 0.9617
# Epoch 14892/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5215 - accuracy: 0.9617
# Epoch 14893/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5215 - accuracy: 0.9617
# Epoch 14894/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5213 - accuracy: 0.9618
# Epoch 14895/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5211 - accuracy: 0.9618
# Epoch 14896/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5213 - accuracy: 0.9618
# Epoch 14897/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5213 - accuracy: 0.9618
# Epoch 14898/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5210 - accuracy: 0.9618
# Epoch 14899/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5213 - accuracy: 0.9618
# Epoch 14900/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5213 - accuracy: 0.9618
# Epoch 14901/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5209 - accuracy: 0.9618
# Epoch 14902/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5209 - accuracy: 0.9618
# Epoch 14903/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5210 - accuracy: 0.9618
# Epoch 14904/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5208 - accuracy: 0.9618
# Epoch 14905/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5209 - accuracy: 0.9618
# Epoch 14906/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5217 - accuracy: 0.9618
# Epoch 14907/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5214 - accuracy: 0.9618
# Epoch 14908/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5224 - accuracy: 0.9618
# Epoch 14909/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5212 - accuracy: 0.9618
# Epoch 14910/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5212 - accuracy: 0.9618
# Epoch 14911/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5215 - accuracy: 0.9618
# Epoch 14912/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5225 - accuracy: 0.9618
# Epoch 14913/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5240 - accuracy: 0.9618
# Epoch 14914/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5237 - accuracy: 0.9618
# Epoch 14915/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5233 - accuracy: 0.9618
# Epoch 14916/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5235 - accuracy: 0.9618
# Epoch 14917/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5228 - accuracy: 0.9618
# Epoch 14918/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5230 - accuracy: 0.9618
# Epoch 14919/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5225 - accuracy: 0.9618
# Epoch 14920/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5224 - accuracy: 0.9618
# Epoch 14921/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5224 - accuracy: 0.9618
# Epoch 14922/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5223 - accuracy: 0.9618
# Epoch 14923/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5223 - accuracy: 0.9618
# Epoch 14924/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5223 - accuracy: 0.9618
# Epoch 14925/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5220 - accuracy: 0.9619
# Epoch 14926/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5214 - accuracy: 0.9618
# Epoch 14927/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5213 - accuracy: 0.9619
# Epoch 14928/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5219 - accuracy: 0.9619
# Epoch 14929/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5220 - accuracy: 0.9618
# Epoch 14930/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5215 - accuracy: 0.9618
# Epoch 14931/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5212 - accuracy: 0.9618
# Epoch 14932/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5215 - accuracy: 0.9618
# Epoch 14933/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5213 - accuracy: 0.9618
# Epoch 14934/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5222 - accuracy: 0.9618
# Epoch 14935/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5223 - accuracy: 0.9618
# Epoch 14936/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5229 - accuracy: 0.9618
# Epoch 14937/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5213 - accuracy: 0.9618
# Epoch 14938/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5217 - accuracy: 0.9618
# Epoch 14939/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5210 - accuracy: 0.9618
# Epoch 14940/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5208 - accuracy: 0.9618
# Epoch 14941/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5217 - accuracy: 0.9618
# Epoch 14942/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5210 - accuracy: 0.9618
# Epoch 14943/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5212 - accuracy: 0.9615
# Epoch 14944/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5208 - accuracy: 0.9614
# Epoch 14945/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5209 - accuracy: 0.9613
# Epoch 14946/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5204 - accuracy: 0.9616
# Epoch 14947/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5206 - accuracy: 0.9618
# Epoch 14948/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5208 - accuracy: 0.9619
# Epoch 14949/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5209 - accuracy: 0.9619
# Epoch 14950/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5212 - accuracy: 0.9618
# Epoch 14951/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5215 - accuracy: 0.9618
# Epoch 14952/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5209 - accuracy: 0.9618
# Epoch 14953/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5212 - accuracy: 0.9618
# Epoch 14954/15000
# 2/2 [==============================] - 4s 2s/step - loss: 0.5213 - accuracy: 0.9618
# Epoch 14955/15000
# 2/2 [==============================] - 4s 2s/step - loss: 0.5209 - accuracy: 0.9618
# Epoch 14956/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5207 - accuracy: 0.9618
# Epoch 14957/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5208 - accuracy: 0.9618
# Epoch 14958/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5203 - accuracy: 0.9618
# Epoch 14959/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5206 - accuracy: 0.9619
# Epoch 14960/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5208 - accuracy: 0.9618
# Epoch 14961/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5216 - accuracy: 0.9618
# Epoch 14962/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5216 - accuracy: 0.9618
# Epoch 14963/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5226 - accuracy: 0.9618
# Epoch 14964/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5236 - accuracy: 0.9618
# Epoch 14965/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5223 - accuracy: 0.9618
# Epoch 14966/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5221 - accuracy: 0.9618
# Epoch 14967/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5229 - accuracy: 0.9618
# Epoch 14968/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5226 - accuracy: 0.9619
# Epoch 14969/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5223 - accuracy: 0.9618
# Epoch 14970/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5229 - accuracy: 0.9618
# Epoch 14971/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5229 - accuracy: 0.9618
# Epoch 14972/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5220 - accuracy: 0.9618
# Epoch 14973/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5219 - accuracy: 0.9618
# Epoch 14974/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5213 - accuracy: 0.9618
# Epoch 14975/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5213 - accuracy: 0.9618
# Epoch 14976/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5221 - accuracy: 0.9618
# Epoch 14977/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5216 - accuracy: 0.9618
# Epoch 14978/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5219 - accuracy: 0.9618
# Epoch 14979/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5221 - accuracy: 0.9619
# Epoch 14980/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5212 - accuracy: 0.9619
# Epoch 14981/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5209 - accuracy: 0.9619
# Epoch 14982/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5210 - accuracy: 0.9619
# Epoch 14983/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5203 - accuracy: 0.9619
# Epoch 14984/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5210 - accuracy: 0.9619
# Epoch 14985/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5212 - accuracy: 0.9618
# Epoch 14986/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5209 - accuracy: 0.9618
# Epoch 14987/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5207 - accuracy: 0.9618
# Epoch 14988/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5208 - accuracy: 0.9618
# Epoch 14989/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5205 - accuracy: 0.9618
# Epoch 14990/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5205 - accuracy: 0.9618
# Epoch 14991/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5207 - accuracy: 0.9618
# Epoch 14992/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5207 - accuracy: 0.9618
# Epoch 14993/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5214 - accuracy: 0.9618
# Epoch 14994/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5207 - accuracy: 0.9619
# Epoch 14995/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5209 - accuracy: 0.9618
# Epoch 14996/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5205 - accuracy: 0.9618
# Epoch 14997/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5200 - accuracy: 0.9618
# Epoch 14998/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5202 - accuracy: 0.9618
# Epoch 14999/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5209 - accuracy: 0.9618
# Epoch 15000/15000
# 2/2 [==============================] - 4s 1s/step - loss: 0.5203 - accuracy: 0.9618
# total computation time =  54368.69440484047
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: domain_adapt_autoenc_epochs.15000.model\assets
# INFO:tensorflow:Assets written to: domain_adapt_autoenc_epochs.15000.model\assets

# %%
import keras
model = keras.models.load_model('domain_adapt_autoenc_epochs.15000.model')

# %%
import numpy as np
import cv2
from keras.utils import img_to_array
# Original image for prediction of output_img 
# this one does not belong to the training set
test_img_data=[]

test_img=cv2.imread('./data/heisenberg_heisenberg/gernot-heisenberg-original.jpg', 1) #Change 0 to 1 for color images
test_img = cv2.cvtColor(test_img, cv2.COLOR_BGR2RGB)#Changing BGR to RGB to show images in true colors
test_img=cv2.resize(test_img,(256,256))
test_img_data.append(img_to_array(test_img))

test_img_array = np.reshape(test_img_data, (len(test_img_data), 256,256, 3))
test_img_array = test_img_array.astype('float32') / 255. # normalize

# %%
import matplotlib.pyplot as plt
print("output of test image")
pred = model.predict(test_img_array)
fig, axes = plt.subplots(1,2)
axes[0].imshow(test_img_array.reshape(256,256, 3))
axes[1].imshow(pred[0].reshape(256, 256, 3))
axes[0].set_xlabel("Original")
axes[1].set_xlabel("Reconstructed")
# Out:
# output of test image
# 1/1 [==============================] - 0s 127ms/step
# Text(0.5, 0, 'Reconstructed')

# %% [markdown]
# Following code to visualize Feature maps in a cnn is based on <a href="https://towardsdatascience.com/convolutional-neural-network-feature-map-and-filter-visualization-f75012a5a49c">this</a> article.

# %%
import tensorflow as tf
img_path='data/heisenberg_heisenberg/gernot-heisenberg-original.jpg'
# Define a new Model, Input= image 
# Output= intermediate representations for all layers in the  
# previous model after the first.
successive_outputs = [layer.output for layer in model.layers[1:]]
#visualization_model = Model(img_input, successive_outputs)
visualization_model = tf.keras.models.Model(inputs = model.input, outputs = successive_outputs)
#Load the input image
img = cv2.imread(img_path,1)
# Convert ht image to Array of dimension (150,150,3)
x   = img_to_array(img)                           
x   = x.reshape((1,) + x.shape)
# Rescale by 1/255
x /= 255.0
# Let's run input image through our vislauization network
# to obtain all intermediate representations for the image.
successive_feature_maps = visualization_model.predict(x)
# Retrieve are the names of the layers, so can have them as part of our plot
layer_names = [layer.name for layer in model.layers]
for layer_name, feature_map in zip(layer_names, successive_feature_maps):
  print(feature_map.shape)
  if len(feature_map.shape) == 4:
    
    # Plot Feature maps for the conv / maxpool layers, not the fully-connected layers
   
    n_features = feature_map.shape[-1]  # number of features in the feature map
    size       = feature_map.shape[ 1]  # feature map shape (1, size, size, n_features)
    
    # We will tile our images in this matrix
    display_grid = np.zeros((size, size * n_features))
    
    # Postprocess the feature to be visually palatable
    for i in range(n_features):
      x  = feature_map[0, :, :, i]
      x -= x.mean()
      x /= x.std ()
      x *=  64
      x += 128
      x  = np.clip(x, 0, 255).astype('uint8')
      # Tile each filter into a horizontal grid
      display_grid[:, i * size : (i + 1) * size] = x
# Display the grid
    scale = 20. / n_features
    plt.figure( figsize=(scale * n_features, scale) )
    plt.title ( layer_name )
    plt.grid  ( False )
    plt.imshow( display_grid, aspect='auto', cmap='viridis' )
# Out:
# 1/1 [==============================] - 0s 109ms/step
# (1, 128, 128, 32)
# (1, 128, 128, 8)
# (1, 64, 64, 8)
# (1, 64, 64, 8)
# (1, 32, 32, 8)
# (1, 32, 32, 8)
# (1, 64, 64, 8)
# (1, 64, 64, 8)
# (1, 128, 128, 8)
# (1, 128, 128, 32)
# (1, 256, 256, 32)
# C:\Users\esser\AppData\Local\Temp\ipykernel_20836\1212167371.py:37: RuntimeWarning: invalid value encountered in divide
#   x /= x.std ()
# (1, 256, 256, 3)
